# %%
import os
import numpy as np
from numpy.linalg import norm
import matplotlib.pyplot as plt
import matplotlib.tri as tri
from scipy.spatial import KDTree
from scipy.interpolate import make_interp_spline
import fipy as fp
import gmsh
import timeit
from tqdm import tqdm

# %%
path='/home/artem.kays/scripts/lncRNAeffects/RNA_diffusion'
out_f = f'{path}/figures/3D_mesh_gen_test/sim_chrom'
os.chdir(path)
from utils.mesh_generation import *
from utils.graphics_3d import *

# %%
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.rcParams['xtick.labelsize']=18
plt.rcParams['ytick.labelsize']=18
plt.rcParams['font.size']=18

# %%
def split_points_into_sets(points, sigma):
    n = len(points)
    if n < 3:
        return {'spline_sets': [], 'sphere_cylinder': list(range(n))}
    
    # Compute angles between consecutive segments for points 1 to n-2 (0-based)
    angles = []
    for i in range(1, n-1):
        vec_prev = np.array(points[i]) - np.array(points[i-1])
        vec_next = np.array(points[i+1]) - np.array(points[i])
        norm_prev = norm(vec_prev)
        norm_next = norm(vec_next)
        if norm_prev == 0 or norm_next == 0:
            # Handle zero-length segments (angle is 0)
            angles.append(0.0)
            continue
        cos_theta = np.dot(vec_prev, vec_next) / (norm_prev * norm_next)
        cos_theta = np.clip(cos_theta, -1.0, 1.0)
        theta = np.arccos(cos_theta)
        angles.append(theta)
    
    # Compute prefix sum of angles
    prefix_sum = [0.0]
    for angle in angles:
        prefix_sum.append(prefix_sum[-1] + angle)
    
    spline_sets = []
    sphere_cylinder = set()
    i = 0
    
    while i < n:
        j = i + 2
        while j < n:
            valid = True
            if j != i + 1:
                vec_prev = np.array(points[j-1]) - np.array(points[j-2])
                vec_next = np.array(points[j]) - np.array(points[j-1])
                norm_prev = norm(vec_prev)
                vec_next = norm(vec_next)
                thres = 1.3*sigma*np.sin(angles[j-2])
            if j != i + 1 and (norm_prev < thres or norm_next < thres):
                # print(i, j, norm_prev, vec_next, thres)
                break
            for k in range(i, j-1):
                cum_angle = prefix_sum[j-1] - prefix_sum[k]
                if cum_angle >= np.pi / 2:
                    point_k = np.array(points[k])
                    point_j = np.array(points[j])
                    dist = np.linalg.norm(point_k - point_j)
                    if dist <= 2 * sigma:
                        # print(i, j, k, dist)
                        valid = False
                        break
            if valid:
                j += 1
            else:
                break
        # Determine if the current segment is a valid spline set
        if j - i >= 3:
            spline_sets.append(list(range(i, j)))
            i = j - 1
        else:
            sphere_cylinder.add(i)
            i = j - 1
    
    # Convert the set to a sorted list
    sphere_cylinder = sorted(sphere_cylinder)
    
    return {
        'spline_sets': spline_sets,
        'sphere_cylinder': sphere_cylinder
    }

# %%
for i in range(7, 7):
    print(i)

# %%
def gmsh_spline_with_volume_3d(points, sigma):
    # Create original spline
    p_tags = []
    # l_tags = []
    for i in range(len(points)):
        p_tags.append(gmsh.model.occ.addPoint(*points[i], 0))
        # if i:
        #     l_tags.append(gmsh.model.occ.addLine(p_tags[-2], p_tags[-1]))
    spline = gmsh.model.occ.addSpline(p_tags)
    
    #beg_circle = gmsh.model.occ.addDisk(*points[0], 0, 0.4*sigma*2, 0.4*sigma*2)
    #end_circle = gmsh.model.occ.addDisk(*points[-1], 0, 0.4*sigma*2, 0.4*sigma*2)

    # A wire is like a curve loop, but open:
    #wire = gmsh.model.occ.addWire(l_tags)
    wire = gmsh.model.occ.addWire([spline])
    
    # We define the shape we would like to extrude along the spline (a circle):
    disk = gmsh.model.occ.addDisk(*points[0], sigma, sigma)
    
    # Compute the axis of rotation (cross product of spline tangent and circle normal)
    spline_tan = points[1] - points[0]
    rotation_axis = np.cross(spline_tan, [0, 0, 1])
    rotation_axis /= np.linalg.norm(rotation_axis)
    
    # We use the dot product between the line vector and the z-axis to get the rotation angle
    angle = np.arcsin(np.abs(spline_tan[2]) / np.linalg.norm(spline_tan)) - np.pi / 2
    gmsh.model.occ.rotate([(2, disk)], *points[0], *rotation_axis, angle)
    
    # We extrude the disk along the spline to create a pipe (other sweeping types
    # can be specified; try e.g. 'Frenet' instead of 'DiscreteTrihedron'):
    chrom = gmsh.model.occ.addPipe([(2, disk)], wire, 'DiscreteTrihedron')
    gmsh.model.occ.remove([(1, spline)])
    gmsh.model.occ.remove([(2, disk)])

    return chrom

# %%
def chrom_3d(points, min_size, scale, sigma, mesh_f, space_scale=1.2, spheres=1, cylinders=1, splines=1):
    """
    Function creates circular 3D mesh with exclusion zone with no nodes and edges corresponding to chromatin.
    Mesh density is uniform in the region beyond the sigma*scale from the exclusion zone and
    follows a power-law dependence with an exponent of -2 within the sigma*scale from the exclusion zone

    **Input**

    -   points   =   Chromatin bins' coordinates
    -   sigma   =   Chromatin thickness (half-width of the exclusion zone with no nodes and edges)
    -   min_size    =   Mesh minimum density
    -   n_nodes    =   (Temporarily non-functional) Number of nodes (current function returns mesh with ~2-fold number of nodes)
    -   scale   =   Distance from the exclusion zone in sigma units within which mesh density
                    follows a power-law dependence with an exponent of -2
    -   output_dir    =   Output dir for mesh .msh2 file
    -   space_scale    =   Scaling factor of the convex hull of the chromatin bins
    """
    
    gmsh.initialize()
    gmsh.model.add("mesh")
    # gmsh.option.setNumber("General.Verbosity", 3)
    gmsh.option.setNumber("General.NumThreads", 16)
    gmsh.option.setNumber("Geometry.NumSubEdges", 1000)
    
    # Create main domain (scaled convex hull)
    # space, sp_vol = gmsh_convex_hull_3d(points, scale=space_scale)
    space = gmsh.model.occ.addBox(points[:,0].min()-3*sigma, points[:,1].min()-3*sigma, -2,
                                  (points[:,0].max()-points[:,0].min())+6*sigma,
                                  (points[:,1].max()-points[:,1].min())+6*sigma, 4)
    space = [(3, space)]

    # Create chromatin
    spline_sets = []
    if splines:
        sets = split_points_into_sets(bin_r, sigma)
        spline_sets = sets['spline_sets']
        sphere_cylinder = sets['sphere_cylinder']
    else:
        sphere_cylinder = range(len(points))

    splines_, spheres_, cylinders_ = [], [], []
    dist = norm(points[1:]-points[:-1], axis=1)
    for i in sphere_cylinder:
        # print(i)
        if spheres:
            #if not splines:
            space = gmsh.model.occ.cut(space, [(3, gmsh.model.occ.addSphere(*points[i], 1.005*sigma))])[0]
            #else:
            # spheres_.append((3, gmsh.model.occ.addSphere(*points[i], 1.005*sigma)))
    # space = gmsh.model.occ.cut(space, spheres_)[0]

    for i in sphere_cylinder:
        if i != len(points) - 1 and cylinders and dist[i] > (4*min_size*(2*sigma - min_size))**0.5/2:
            #if not splines:
            space = gmsh.model.occ.cut(space, [(3, gmsh.model.occ.addCylinder(*points[i], *(points[i+1]-points[i]), sigma))])[0]
            #else:
            # cylinders_.append((3, gmsh.model.occ.addCylinder(*points[i], *(points[i+1]-points[i]), sigma)))
            # print('Gap!')
    # space = gmsh.model.occ.cut(space, cylinders_)[0]

    for spline in spline_sets:
        space = gmsh.model.occ.cut(space, [(3, gmsh.model.occ.addSphere(*points[spline[0]], 1.005*sigma))])[0]
        # spheres_.append((3, gmsh.model.occ.addSphere(*points[spline[0]], 1.005*sigma)))
        splines_.extend(gmsh_spline_with_volume_3d(points[spline[0]:(spline[-1]+1)], sigma))
        # space = gmsh.model.occ.cut(space, gmsh_spline_with_volume_3d(points[spline[0]:(spline[-1]+1)], sigma))[0]
    # splines_ = gmsh.model.occ.fuse(splines_, splines_)[0]
    # print(gmsh.model.occ.getEntities(dim=3))
    # space = gmsh.model.occ.cut(space, spheres_)[0]
    if splines_:
         space = gmsh.model.occ.cut(space, splines_)[0]
    gmsh.model.occ.synchronize()
    
    # (Temporarily non-functional) Evaluate min mesh size for generating required number of nodes
    # min_size=mesh_min_size_chrom_3d(points, n_nodes, sigma, scale, sp_vol)

    # Get chromatin surface
    s_tags=[s[1] for s in gmsh.model.occ.getEntities(dim=2) if gmsh.model.getType(*s) != 'Plane']
    
    # Configure mesh size field (graded from exclusion_radius)
    distance_field = gmsh.model.mesh.field.add("Distance")
    gmsh.model.mesh.field.setNumbers(distance_field, "FacesList", s_tags)
    
    # Use for large distances between adjacent bins
    # gmsh.model.mesh.field.setNumber(distance_field, "Sampling", 100)
    
    threshold_field = gmsh.model.mesh.field.add("Threshold")
    gmsh.model.mesh.field.setNumber(threshold_field, "InField", distance_field)
    gmsh.model.mesh.field.setNumber(threshold_field, "SizeMin", min_size)
    gmsh.model.mesh.field.setNumber(threshold_field, "SizeMax", min_size*scale**2)
    gmsh.model.mesh.field.setNumber(threshold_field, "DistMin", 0)
    gmsh.model.mesh.field.setNumber(threshold_field, "DistMax", sigma*scale)
    
    # Remove entities for cleaner mesh
    # gmsh.model.occ.remove(gmsh.model.occ.getEntities(dim=1))
    # gmsh.model.occ.remove(gmsh.model.occ.getEntities(dim=2))
    # gmsh.model.occ.synchronize()
    
    # Generate and save the mesh
    gmsh.model.mesh.field.setAsBackgroundMesh(threshold_field)
    gmsh.option.setNumber("Mesh.MeshSizeExtendFromBoundary", 0)
    gmsh.option.setNumber("Mesh.MeshSizeFromPoints", 0)
    gmsh.option.setNumber("Mesh.MeshSizeFromCurvature", 0)
    gmsh.option.setNumber("Mesh.Algorithm", 1)

    # This may resolve some BOPAlgo alerts and related errors
    # gmsh.model.mesh.generate(2)
    # gmsh.model.mesh.refine()
    
    gmsh.model.mesh.generate(3)
    gmsh.write(mesh_f)
    
    gmsh.finalize()

# %%
def mesh_triang(mesh, mask_z, mode_cells=1):
    if mode_cells:
        triang = tri.Triangulation(mesh.x.value[mask_z], mesh.y.value[mask_z])
        mask_b_1 = np.all(np.any(mesh.exteriorFaces.value[mesh.cellFaceIDs.data[:, mask_z]], axis=0)[triang.triangles], axis=1)
        mask_b_2 = (KDTree(bin_r).query(np.mean(mesh.cellCenters.value[:,mask_z].T[triang.triangles], axis=1))[0]<sigma)
        triang.set_mask(mask_b_1)# | mask_b_2)
        # triang.set_mask(mask_b)
    else:
        triang = tri.Triangulation(mesh.faceCenters.value[0], mesh.faceCenters.value[1])
        triang.set_mask(np.all(mesh.exteriorFaces.value[triang.triangles], axis=1))

    return triang

# %%
def plot_test_mesh(bin_r, min_size, scale, sigma, spheres, cylinders, splines):
    if not os.path.exists(f'{out_f}_tmp'):
        os.mkdir(f'{out_f}_tmp')
    print('Duration: ' + str(timeit.timeit(
          lambda: chrom_3d(bin_r, min_size, scale, sigma, f'{out_f}_tmp/3d_mesh_test.msh2',
                         spheres=spheres, cylinders=cylinders, splines=splines), number=1)
         ))
    mesh = fp.Gmsh3D(f'{out_f}_tmp/3d_mesh_test.msh2')
    print(f'mesh.cellCenters.shape: {mesh.cellCenters.shape}')

    plane_pos, thres = 0.5, min_size / 2
    plane = mesh.z.value.min() + plane_pos * (mesh.z.value.max() - mesh.z.value.min())
    mask_z = (abs(mesh.z.value - plane) < thres)

    triang = mesh_triang(mesh, mask_z, mode_cells=1)
    
    fig, ax = plt.subplots(figsize=(8,5))
    ax.triplot(triang, lw=0.1)
    plot_curve_with_opacity(ax, bin_r, z_plane=plane, num_segments=1, global_max=0, visibility=1)
    plt.scatter(bin_r[:, 0], bin_r[:, 1], s=5, c='black')
    
    ax.set_xlim(np.min(mesh.x.value[mask_z])*1.05, np.max(mesh.x.value[mask_z])*1.05)
    ax.set_ylim(np.min(mesh.y.value[mask_z])*1.05, np.max(mesh.y.value[mask_z])*1.05)
    ax.set_aspect('equal', adjustable='box')

    os.remove(f'{out_f}_tmp/3d_mesh_test.msh2')
    os.rmdir(f'{out_f}_tmp')

# %%
min_size, scale, sigma = 0.1, 5, 0.5

# %%
#ang, dspr = np.pi*1/4, 0.1
#r, ang = 1.3*sigma*np.sin(ang), np.pi - ang
#bin_r = [[dspr*r*np.cos(ang),dspr*r*np.sin(ang),0], [0,0,0], [1/dspr*r,0,0], [1/dspr*r-dspr*r*np.cos(ang),dspr*r*np.sin(ang),0]]

# bin_r = [[0,0,0],[1,2,0],[2,0,0],[3,2,0],[4,0,0],[5,2,0]]
bin_r = np.array([[0,0,-0.2],[4,1,-0.1],[3,2,0],[2,2,0],[1,1,0.1],[5,0,0.2]])
# bin_r[:, 1] *= 2
bin_r = (bin_r - np.mean(bin_r, axis=0))

fig, ax = plt.subplots()
plot_curve_with_opacity(ax, bin_r, z_plane=0, num_segments=10, global_max=0, visibility=0.95)
ax.set_xlim(np.min(bin_r[:, 0])*1.05, np.max(bin_r[:, 0])*1.05)
ax.set_ylim(np.min(bin_r[:, 1])*1.05, np.max(bin_r[:, 1])*1.05)
ax.set_aspect('equal', adjustable='box')

# %%
dist = norm(bin_r[1:]-bin_r[:-1], axis=1)
u_c = np.r_[0, np.cumsum(dist**0.5)]
spl = make_interp_spline(u_c, bin_r, axis=0)
uu = np.linspace(u_c[0], u_c[-1], len(dist)*10)
bin_r = spl(uu)

# %%
fig, ax = plt.subplots()
# plot_curve_with_opacity(ax, bin_r, z_plane=0, num_segments=1, global_max=0, visibility=0.95)
plt.scatter(bin_r[:, 0], bin_r[:, 1], s=20, c='black')
plt.scatter(spl(u_c)[:, 0], spl(u_c)[:, 1], s=20, c='r')
ax.set_xlim(np.min(bin_r[:, 0])*1.05, np.max(bin_r[:, 0])*1.05)
ax.set_ylim(np.min(bin_r[:, 1])*1.05, np.max(bin_r[:, 1])*1.05)
ax.set_aspect('equal', adjustable='box')

# fig.savefig(fname=f'{out_f}.svg', bbox_inches='tight', format='svg')
# fig.savefig(fname=f'{out_f}.png', bbox_inches='tight', dpi=300, format='png')

# %%
dist_r = bin_r[1:]-bin_r[:-1]
dist = norm(dist_r, axis=1)
cos_ = (dist_r[:-1] * dist_r[1:]).sum(1) / dist[:-1] / dist[1:]
fig, ax = plt.subplots(1, 2, figsize=(12,4))
ax[0].plot(dist, c='black')
ax[0].set_title('Interbin distance')
ax[1].plot(np.arccos(cos_) / np.pi, c='black')
ax[1].set_title(r'$\frac{angle}{\pi}$ for adjacent interbin vectors')

# fig.savefig(fname=f'{out_f}_geom.svg', bbox_inches='tight', format='svg')
# fig.savefig(fname=f'{out_f}_geom.png', bbox_inches='tight', dpi=300, format='png')
# Out:
# Text(0.5, 1.0, '$\\frac{angle}{\\pi}$ for adjacent interbin vectors')

# %%
plot_test_mesh(bin_r, min_size, scale, sigma=0.5, spheres=1, cylinders=1, splines=0)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [  0%] Meshing curve 2 (Line)
# Info    : [  0%] Meshing curve 3 (Line)
# Info    : [  0%] Meshing curve 6 (Line)
# Info    : [  0%] Meshing curve 7 (Line)
# Info    : [  0%] Meshing curve 8 (Line)
# Info    : [  0%] Meshing curve 13 (Circle)
# Info    : [  0%] Meshing curve 10 (Line)
# Info    : [  0%] Meshing curve 16 (Circle)
# Info    : [  0%] Meshing curve 11 (Line)
# Info    : [  0%] Meshing curve 4 (Line)
# Info    : [  0%] Meshing curve 12 (Line)
# Info    : [  0%] Meshing curve 5 (Line)
# Info    : [  0%] Meshing curve 9 (Line)
# Info    : [  0%] Meshing curve 14 (Circle)
# Info    : [  0%] Meshing curve 17 (Circle)
# Info    : [  0%] Meshing curve 18 (Circle)
# Info    : [  0%] Meshing curve 20 (BSpline)
# Info    : [  0%] Meshing curve 21 (BSpline)
# Info    : [  0%] Meshing curve 22 (BSpline)
# Info    : [  0%] Meshing curve 23 (Circle)
# Info    : [  0%] Meshing curve 24 (BSpline)
# Info    : [  0%] Meshing curve 25 (Line)
# Info    : [  0%] Meshing curve 26 (Circle)
# Info    : [  0%] Meshing curve 27 (Circle)
# Info    : [  0%] Meshing curve 28 (Circle)
# Info    : [  0%] Meshing curve 30 (Circle)
# Info    : [ 10%] Meshing curve 31 (Circle)
# Info    : [ 10%] Meshing curve 32 (Circle)
# Info    : [ 10%] Meshing curve 34 (Circle)
# Info    : [ 10%] Meshing curve 35 (Circle)
# Info    : [ 10%] Meshing curve 37 (Circle)
# Info    : [ 10%] Meshing curve 38 (Circle)
# Info    : [ 10%] Meshing curve 39 (Circle)
# Info    : [ 10%] Meshing curve 41 (Circle)
# Info    : [ 10%] Meshing curve 42 (Circle)
# Info    : [ 10%] Meshing curve 43 (BSpline)
# Info    : [ 10%] Meshing curve 44 (Circle)
# Info    : [ 10%] Meshing curve 45 (Circle)
# Info    : [ 10%] Meshing curve 46 (BSpline)
# Info    : [ 10%] Meshing curve 47 (Circle)
# Info    : [ 10%] Meshing curve 48 (BSpline)
# Info    : [ 10%] Meshing curve 49 (Circle)
# Info    : [ 10%] Meshing curve 50 (Circle)
# Info    : [ 10%] Meshing curve 52 (Circle)
# Info    : [ 10%] Meshing curve 53 (Circle)
# Info    : [ 10%] Meshing curve 54 (Circle)
# Info    : [ 10%] Meshing curve 55 (Circle)
# Info    : [ 10%] Meshing curve 57 (Circle)
# Info    : [ 10%] Meshing curve 59 (Circle)
# Info    : [ 10%] Meshing curve 60 (Circle)
# Info    : [ 10%] Meshing curve 62 (Circle)
# Info    : [ 10%] Meshing curve 63 (Circle)
# Info    : [ 20%] Meshing curve 64 (Circle)
# Info    : [ 20%] Meshing curve 66 (BSpline)
# Info    : [ 20%] Meshing curve 67 (BSpline)
# Info    : [ 20%] Meshing curve 68 (Circle)
# Info    : [ 20%] Meshing curve 69 (BSpline)
# Info    : [ 20%] Meshing curve 70 (Circle)
# Info    : [ 20%] Meshing curve 71 (Circle)
# Info    : [ 20%] Meshing curve 72 (BSpline)
# Info    : [ 20%] Meshing curve 73 (Circle)
# Info    : [ 20%] Meshing curve 74 (Circle)
# Info    : [ 20%] Meshing curve 76 (Circle)
# Info    : [ 20%] Meshing curve 77 (Circle)
# Info    : [ 20%] Meshing curve 79 (Circle)
# Info    : [ 20%] Meshing curve 80 (Circle)
# Info    : [ 20%] Meshing curve 82 (Circle)
# Info    : [ 20%] Meshing curve 83 (BSpline)
# Info    : [ 20%] Meshing curve 84 (Circle)
# Info    : [ 20%] Meshing curve 85 (BSpline)
# Info    : [ 20%] Meshing curve 86 (BSpline)
# Info    : [ 20%] Meshing curve 87 (Circle)
# Info    : [ 20%] Meshing curve 88 (Circle)
# Info    : [ 20%] Meshing curve 91 (Circle)
# Info    : [ 20%] Meshing curve 92 (Circle)
# Info    : [ 20%] Meshing curve 93 (Circle)
# Info    : [ 20%] Meshing curve 94 (BSpline)
# Info    : [ 20%] Meshing curve 95 (BSpline)
# Info    : [ 20%] Meshing curve 96 (Circle)
# Info    : [ 20%] Meshing curve 97 (Line)
# Info    : [ 20%] Meshing curve 98 (Circle)
# Info    : [ 20%] Meshing curve 99 (Circle)
# Info    : [ 20%] Meshing curve 101 (Circle)
# Info    : [ 20%] Meshing curve 102 (Circle)
# Info    : [ 20%] Meshing curve 104 (Circle)
# Info    : [ 20%] Meshing curve 105 (BSpline)
# Info    : [ 20%] Meshing curve 106 (Circle)
# Info    : [ 20%] Meshing curve 107 (Circle)
# Info    : [ 20%] Meshing curve 108 (Circle)
# Info    : [ 20%] Meshing curve 109 (Circle)
# Info    : [ 20%] Meshing curve 111 (Circle)
# Info    : [ 20%] Meshing curve 112 (Circle)
# Info    : [ 20%] Meshing curve 113 (BSpline)
# Info    : [ 30%] Meshing curve 114 (Line)
# Info    : [ 30%] Meshing curve 115 (Circle)
# Info    : [ 30%] Meshing curve 116 (Circle)
# Info    : [ 30%] Meshing curve 117 (Circle)
# Info    : [ 30%] Meshing curve 118 (BSpline)
# Info    : [ 30%] Meshing curve 119 (Circle)
# Info    : [ 30%] Meshing curve 120 (Circle)
# Info    : [ 30%] Meshing curve 122 (Circle)
# Info    : [ 30%] Meshing curve 123 (Circle)
# Info    : [ 30%] Meshing curve 125 (Circle)
# Info    : [ 30%] Meshing curve 126 (Circle)
# Info    : [ 30%] Meshing curve 128 (BSpline)
# Info    : [ 30%] Meshing curve 129 (Circle)
# Info    : [ 30%] Meshing curve 130 (Circle)
# Info    : [ 30%] Meshing curve 131 (BSpline)
# Info    : [ 30%] Meshing curve 132 (BSpline)
# Info    : [ 40%] Meshing curve 133 (Circle)
# Info    : [ 40%] Meshing curve 134 (Circle)
# Info    : [ 40%] Meshing curve 135 (Circle)
# Info    : [ 40%] Meshing curve 137 (BSpline)
# Info    : [ 40%] Meshing curve 138 (BSpline)
# Info    : [ 40%] Meshing curve 139 (Line)
# Info    : [ 40%] Meshing curve 140 (BSpline)
# Info    : [ 40%] Meshing curve 141 (BSpline)
# Info    : [ 40%] Meshing curve 142 (Circle)
# Info    : [ 40%] Meshing curve 143 (Circle)
# Info    : [ 40%] Meshing curve 145 (Circle)
# Info    : [ 40%] Meshing curve 146 (Circle)
# Info    : [ 40%] Meshing curve 148 (Circle)
# Info    : [ 40%] Meshing curve 149 (BSpline)
# Info    : [ 40%] Meshing curve 150 (Line)
# Info    : [ 40%] Meshing curve 151 (BSpline)
# Info    : [ 40%] Meshing curve 152 (BSpline)
# Info    : [ 40%] Meshing curve 153 (Circle)
# Info    : [ 40%] Meshing curve 155 (Circle)
# Info    : [ 40%] Meshing curve 156 (Circle)
# Info    : [ 40%] Meshing curve 157 (Circle)
# Info    : [ 40%] Meshing curve 158 (Circle)
# Info    : [ 40%] Meshing curve 159 (Circle)
# Info    : [ 40%] Meshing curve 160 (Circle)
# Info    : [ 40%] Meshing curve 161 (Circle)
# Info    : [ 40%] Meshing curve 163 (Circle)
# Info    : [ 40%] Meshing curve 164 (Circle)
# Info    : [ 40%] Meshing curve 166 (Circle)
# Info    : [ 40%] Meshing curve 167 (BSpline)
# Info    : [ 40%] Meshing curve 168 (BSpline)
# Info    : [ 40%] Meshing curve 169 (Circle)
# Info    : [ 40%] Meshing curve 170 (Circle)
# Info    : [ 40%] Meshing curve 171 (Circle)
# Info    : [ 40%] Meshing curve 173 (Circle)
# Info    : [ 40%] Meshing curve 174 (BSpline)
# Info    : [ 40%] Meshing curve 175 (Line)
# Info    : [ 40%] Meshing curve 176 (BSpline)
# Info    : [ 40%] Meshing curve 177 (Circle)
# Info    : [ 40%] Meshing curve 181 (Circle)
# Info    : [ 40%] Meshing curve 182 (Circle)
# Info    : [ 40%] Meshing curve 184 (Circle)
# Info    : [ 40%] Meshing curve 185 (BSpline)
# Info    : [ 40%] Meshing curve 186 (Line)
# Info    : [ 40%] Meshing curve 187 (BSpline)
# Info    : [ 40%] Meshing curve 178 (Circle)
# Info    : [ 40%] Meshing curve 188 (BSpline)
# Info    : [ 40%] Meshing curve 189 (Circle)
# Info    : [ 40%] Meshing curve 190 (Circle)
# Info    : [ 40%] Meshing curve 191 (Circle)
# Info    : [ 40%] Meshing curve 192 (Circle)
# Info    : [ 40%] Meshing curve 193 (Circle)
# Info    : [ 40%] Meshing curve 179 (Circle)
# Info    : [ 40%] Meshing curve 194 (Circle)
# Info    : [ 40%] Meshing curve 196 (Circle)
# Info    : [ 40%] Meshing curve 197 (Circle)
# Info    : [ 40%] Meshing curve 199 (Circle)
# Info    : [ 40%] Meshing curve 200 (Circle)
# Info    : [ 40%] Meshing curve 202 (Circle)
# Info    : [ 40%] Meshing curve 203 (BSpline)
# Info    : [ 40%] Meshing curve 204 (BSpline)
# Info    : [ 40%] Meshing curve 205 (Circle)
# Info    : [ 40%] Meshing curve 206 (Circle)
# Info    : [ 40%] Meshing curve 207 (Circle)
# Info    : [ 40%] Meshing curve 208 (Circle)
# Info    : [ 40%] Meshing curve 210 (Circle)
# Info    : [ 40%] Meshing curve 211 (Line)
# Info    : [ 40%] Meshing curve 212 (BSpline)
# Info    : [ 40%] Meshing curve 213 (Circle)
# Info    : [ 40%] Meshing curve 214 (Circle)
# Info    : [ 40%] Meshing curve 215 (Circle)
# Info    : [ 40%] Meshing curve 217 (Circle)
# Info    : [ 40%] Meshing curve 218 (Circle)
# Info    : [ 40%] Meshing curve 220 (BSpline)
# Info    : [ 40%] Meshing curve 221 (BSpline)
# Info    : [ 40%] Meshing curve 222 (Circle)
# Info    : [ 40%] Meshing curve 223 (BSpline)
# Info    : [ 40%] Meshing curve 224 (BSpline)
# Info    : [ 60%] Meshing curve 225 (Line)
# Info    : [ 60%] Meshing curve 226 (Circle)
# Info    : [ 60%] Meshing curve 227 (Circle)
# Info    : [ 60%] Meshing curve 228 (BSpline)
# Info    : [ 60%] Meshing curve 229 (Circle)
# Info    : [ 60%] Meshing curve 231 (BSpline)
# Info    : [ 60%] Meshing curve 232 (Circle)
# Info    : [ 60%] Meshing curve 233 (Circle)
# Info    : [ 60%] Meshing curve 235 (Circle)
# Info    : [ 60%] Meshing curve 236 (Circle)
# Info    : [ 60%] Meshing curve 239 (Circle)
# Info    : [ 60%] Meshing curve 240 (Circle)
# Info    : [ 60%] Meshing curve 241 (Circle)
# Info    : [ 60%] Meshing curve 242 (BSpline)
# Info    : [ 60%] Meshing curve 243 (Circle)
# Info    : [ 60%] Meshing curve 245 (Circle)
# Info    : [ 60%] Meshing curve 246 (Circle)
# Info    : [ 60%] Meshing curve 247 (BSpline)
# Info    : [ 60%] Meshing curve 248 (Circle)
# Info    : [ 60%] Meshing curve 249 (BSpline)
# Info    : [ 60%] Meshing curve 250 (Circle)
# Info    : [ 60%] Meshing curve 251 (Circle)
# Info    : [ 60%] Meshing curve 252 (Circle)
# Info    : [ 60%] Meshing curve 253 (Circle)
# Info    : [ 60%] Meshing curve 255 (Circle)
# Info    : [ 60%] Meshing curve 256 (Circle)
# Info    : [ 60%] Meshing curve 258 (Circle)
# Info    : [ 60%] Meshing curve 259 (Circle)
# Info    : [ 60%] Meshing curve 261 (BSpline)
# Info    : [ 60%] Meshing curve 262 (BSpline)
# Info    : [ 70%] Meshing curve 263 (BSpline)
# Info    : [ 70%] Meshing curve 264 (BSpline)
# Info    : [ 70%] Meshing curve 265 (Circle)
# Info    : [ 70%] Meshing curve 266 (BSpline)
# Info    : [ 70%] Meshing curve 268 (Circle)
# Info    : [ 70%] Meshing curve 269 (Circle)
# Info    : [ 70%] Meshing curve 270 (Circle)
# Info    : [ 70%] Meshing curve 271 (BSpline)
# Info    : [ 70%] Meshing curve 272 (Circle)
# Info    : [ 70%] Meshing curve 273 (Circle)
# Info    : [ 70%] Meshing curve 274 (Circle)
# Info    : [ 70%] Meshing curve 276 (Circle)
# Info    : [ 70%] Meshing curve 277 (Circle)
# Info    : [ 70%] Meshing curve 279 (Circle)
# Info    : [ 70%] Meshing curve 280 (Circle)
# Info    : [ 70%] Meshing curve 281 (Circle)
# Info    : [ 70%] Meshing curve 283 (Circle)
# Info    : [ 70%] Meshing curve 284 (Circle)
# Info    : [ 70%] Meshing curve 285 (BSpline)
# Info    : [ 70%] Meshing curve 286 (Circle)
# Info    : [ 70%] Meshing curve 289 (Circle)
# Info    : [ 70%] Meshing curve 290 (Circle)
# Info    : [ 70%] Meshing curve 291 (Circle)
# Info    : [ 70%] Meshing curve 292 (Circle)
# Info    : [ 70%] Meshing curve 293 (Circle)
# Info    : [ 70%] Meshing curve 295 (Circle)
# Info    : [ 70%] Meshing curve 296 (Circle)
# Info    : [ 70%] Meshing curve 297 (Line)
# Info    : [ 70%] Meshing curve 298 (BSpline)
# Info    : [ 70%] Meshing curve 299 (BSpline)
# Info    : [ 70%] Meshing curve 300 (Circle)
# Info    : [ 70%] Meshing curve 301 (Circle)
# Info    : [ 70%] Meshing curve 303 (Circle)
# Info    : [ 70%] Meshing curve 304 (Circle)
# Info    : [ 70%] Meshing curve 307 (Circle)
# Info    : [ 70%] Meshing curve 308 (Circle)
# Info    : [ 70%] Meshing curve 309 (Circle)
# Info    : [ 70%] Meshing curve 311 (Circle)
# Info    : [ 70%] Meshing curve 313 (Circle)
# Info    : [ 70%] Meshing curve 315 (Circle)
# Info    : [ 70%] Meshing curve 316 (Circle)
# Info    : [ 70%] Meshing curve 318 (Circle)
# Info    : [ 70%] Meshing curve 319 (Circle)
# Info    : [ 70%] Meshing curve 322 (Circle)
# Info    : [ 70%] Meshing curve 324 (Circle)
# Info    : [ 70%] Meshing curve 325 (Circle)
# Info    : [ 70%] Meshing curve 326 (Circle)
# Info    : [ 70%] Meshing curve 327 (Circle)
# Info    : [ 70%] Meshing curve 329 (Circle)
# Info    : [ 90%] Meshing curve 330 (Circle)
# Info    : [ 90%] Meshing curve 332 (Circle)
# Info    : [ 90%] Meshing curve 334 (Circle)
# Info    : [ 90%] Meshing curve 336 (Circle)
# Info    : [ 90%] Meshing curve 337 (Circle)
# Info    : [ 90%] Meshing curve 338 (Circle)
# Info    : [ 90%] Meshing curve 339 (Circle)
# Info    : [ 90%] Meshing curve 341 (Circle)
# Info    : [ 90%] Meshing curve 342 (Circle)
# Info    : [ 90%] Meshing curve 344 (Circle)
# Info    : [ 90%] Meshing curve 346 (Circle)
# Info    : [ 90%] Meshing curve 348 (Circle)
# Info    : [ 90%] Meshing curve 349 (Circle)
# Info    : [ 90%] Meshing curve 350 (Circle)
# Info    : [ 90%] Meshing curve 351 (Circle)
# Info    : [ 90%] Meshing curve 353 (Circle)
# Info    : [ 90%] Meshing curve 354 (Circle)
# Info    : [ 90%] Meshing curve 356 (Circle)
# Info    : [ 90%] Meshing curve 358 (Circle)
# Info    : [ 90%] Meshing curve 360 (Circle)
# Info    : [ 90%] Meshing curve 361 (Circle)
# Info    : [ 90%] Meshing curve 362 (Circle)
# Info    : [ 90%] Meshing curve 363 (Circle)
# Info    : [ 90%] Meshing curve 365 (Circle)
# Info    : [ 90%] Meshing curve 366 (Circle)
# Info    : [ 90%] Meshing curve 368 (Circle)
# Info    : [ 90%] Meshing curve 370 (Circle)
# Info    : [ 90%] Meshing curve 372 (Circle)
# Info    : [ 90%] Meshing curve 373 (Circle)
# Info    : [ 90%] Meshing curve 374 (Circle)
# Info    : [ 90%] Meshing curve 375 (Circle)
# Info    : [ 90%] Meshing curve 377 (Circle)
# Info    : [ 90%] Meshing curve 378 (Circle)
# Info    : [ 90%] Meshing curve 380 (Circle)
# Info    : [ 90%] Meshing curve 382 (Circle)
# Info    : [ 90%] Meshing curve 384 (Circle)
# Info    : [ 90%] Meshing curve 385 (Circle)
# Info    : [ 90%] Meshing curve 386 (Circle)
# Info    : [ 90%] Meshing curve 388 (Circle)
# Info    : Done meshing 1D (Wall 0.871822s, CPU 13.3879s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 13 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 3 (Plane, MeshAdapt)
# Info    : [  0%] Meshing surface 9 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 10 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 16 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 4 (Plane, MeshAdapt)
# Info    : [  0%] Meshing surface 5 (Plane, MeshAdapt)
# Info    : [  0%] Meshing surface 15 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 14 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 6 (Plane, MeshAdapt)
# Info    : [  0%] Meshing surface 8 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 7 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 11 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 2 (Plane, MeshAdapt)
# Info    : [  0%] Meshing surface 1 (Plane, MeshAdapt)
# Info    : [  0%] Meshing surface 12 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 17 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 18 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 19 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 20 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 21 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 22 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 23 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 24 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 25 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 26 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 27 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 28 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 29 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 30 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 31 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 32 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 33 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 34 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 35 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 36 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 37 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 38 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 39 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 40 (Cylinder, MeshAdapt)
# Info    : [  0%] Meshing surface 41 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 42 (Sphere, MeshAdapt)
# Info    : [  0%] Meshing surface 43 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 44 (Cylinder, MeshAdapt)
# Info    : [ 40%] Meshing surface 45 (Cylinder, MeshAdapt)
# Info    : [ 40%] Meshing surface 46 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 47 (Cylinder, MeshAdapt)
# Info    : [ 40%] Meshing surface 48 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 49 (Cylinder, MeshAdapt)
# Info    : [ 40%] Meshing surface 50 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 51 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 52 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 53 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 54 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 55 (Cylinder, MeshAdapt)
# Info    : [ 40%] Serializing surface 20 and refining all its bounding edges
# Info    : [ 40%] Meshing surface 56 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 57 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 58 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 59 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 60 (Cylinder, MeshAdapt)
# Info    : [ 40%] Meshing surface 61 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 62 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 63 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 64 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 65 (Sphere, MeshAdapt)
# Info    : [ 40%] Meshing surface 66 (Sphere, MeshAdapt)
# Info    : [ 70%] Meshing surface 67 (Sphere, MeshAdapt)
# Info    : [ 70%] Meshing surface 68 (Sphere, MeshAdapt)
# Info    : [ 70%] Meshing surface 69 (Sphere, MeshAdapt)
# Info    : [ 70%] Meshing surface 70 (Sphere, MeshAdapt)
# Info    : [ 70%] Meshing surface 71 (Sphere, MeshAdapt)
# Info    : [ 70%] Meshing surface 72 (Sphere, MeshAdapt)
# Info    : [ 70%] Meshing surface 73 (Sphere, MeshAdapt)
# Info    : [ 70%] Meshing surface 74 (Sphere, MeshAdapt)
# Info    : [ 70%] Meshing surface 75 (Sphere, MeshAdapt)
# Info    : [ 70%] Meshing surface 76 (Sphere, MeshAdapt)
# Warning : 2 elements remain invalid in surface 20
# Info    : [100%] Meshing surface 20 (Sphere, MeshAdapt)
# Info    : [100%] Surface 20 has self-intersections in its 1D mesh: serializing this one
# Info    : [100%] Meshing surface 20 (Sphere, MeshAdapt)
# Info    : [100%] Surface 20 has self-intersections in its 1D mesh: serializing this one
# Info    : [100%] Meshing surface 20 (Sphere, MeshAdapt)
# Info    : [100%] Surface 20 has self-intersections in its 1D mesh: serializing this one
# Info    : [100%] Meshing surface 20 (Sphere, MeshAdapt)
# Info    : [100%] 8-| Splitting those edges and trying again
# Info    : [100%] :-) All edges recovered after 1 iteration
# Info    : [100%] Meshing surface 25 (Sphere, MeshAdapt)
# Info    : [100%] Meshing surface 16 (Sphere, MeshAdapt)
# Info    : Done meshing 2D (Wall 0.446328s, CPU 6.70221s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 4581 nodes...
# Info    : Done tetrahedrizing 4589 nodes (Wall 0.103653s, CPU 0.099822s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.212405s, CPU 0.20572s)
# Info    : Found volume 1
# Info    : Found void region
# Info    : It. 0 - 0 nodes created - worst tet radius 11.1632 (nodes removed 0 0)
# Info    : It. 500 - 476 nodes created - worst tet radius 1.77713 (nodes removed 0 24)
# Info    : It. 1000 - 965 nodes created - worst tet radius 1.28623 (nodes removed 0 35)
# Info    : It. 1500 - 1459 nodes created - worst tet radius 1.06661 (nodes removed 0 41)
# Info    : 3D refinement terminated (6334 nodes total):
# Info    :  - 5 Delaunay cavities modified for star shapeness
# Info    :  - 47 nodes could not be inserted
# Info    :  - 24707 tetrahedra created in 0.298936 sec. (82649 tets/s)
# Info    : 3 node relocations
# Info    : Done meshing 3D (Wall 0.840841s, CPU 0.837135s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 157.499) with worst = 0.000886475 / average = 0.606046:
# Info    : 0.00 < quality < 0.10 :       191 elements
# Info    : 0.10 < quality < 0.20 :       441 elements
# Info    : 0.20 < quality < 0.30 :       669 elements
# Info    : 0.30 < quality < 0.40 :      1467 elements
# Info    : 0.40 < quality < 0.50 :      3824 elements
# Info    : 0.50 < quality < 0.60 :      5325 elements
# Info    : 0.60 < quality < 0.70 :      5179 elements
# Info    : 0.70 < quality < 0.80 :      3796 elements
# Info    : 0.80 < quality < 0.90 :      2638 elements
# Info    : 0.90 < quality < 1.00 :      1177 elements
# Info    : 1051 edge swaps, 82 node relocations (volume = 157.499): worst = 0.00105846 / average = 0.624088 (Wall 0.0333092s, CPU 0.034353s)
# Info    : 1128 edge swaps, 125 node relocations (volume = 157.499): worst = 0.00105846 / average = 0.624526 (Wall 0.0457618s, CPU 0.047138s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :        20 elements
# Info    : 0.10 < quality < 0.20 :        54 elements
# Info    : 0.20 < quality < 0.30 :       109 elements
# Info    : 0.30 < quality < 0.40 :      1543 elements
# Info    : 0.40 < quality < 0.50 :      3799 elements
# Info    : 0.50 < quality < 0.60 :      5264 elements
# Info    : 0.60 < quality < 0.70 :      5190 elements
# Info    : 0.70 < quality < 0.80 :      3910 elements
# Info    : 0.80 < quality < 0.90 :      2652 elements
# Info    : 0.90 < quality < 1.00 :      1165 elements
# Info    : Done optimizing mesh (Wall 0.0838516s, CPU 0.085422s)
# Info    : 6334 nodes 35239 elements
# Info    : Writing '/home/artem.kays/scripts/lncRNAeffects/RNA_diffusion/figures/3D_mesh_gen_test/sim_chrom_tmp/3d_mesh_test.msh2'...
# Info    : Done writing '/home/artem.kays/scripts/lncRNAeffects/RNA_diffusion/figures/3D_mesh_gen_test/sim_chrom_tmp/3d_mesh_test.msh2'
# Duration: 12.541629495099187
# Warning : ------------------------------
# Warning : Mesh generation error summary
# Warning :     1 warning
# Warning :     0 errors
# Warning : Check the full log for details
# Warning : ------------------------------
# mesh.cellCenters.shape: (3, 23835)

# %%
gmsh.finalize()

# %%
triang = mesh_triang(mesh, mask_z, mode_cells=1)

fig, ax = plt.subplots(figsize=(8,5))
ax.triplot(triang, lw=0.1)
plot_curve_with_opacity(ax, bin_r, z_plane=plane, num_segments=1, global_max=0, visibility=1)
plt.scatter(bin_r[:, 0], bin_r[:, 1], s=15, c='black')

ax.set_xlim(-5, 0)
ax.set_ylim(-3, 1)
ax.set_aspect('equal', adjustable='box')

# fig.savefig(fname=f'{out_f}_spheres.svg', bbox_inches='tight', format='svg')
# fig.savefig(fname=f'{out_f}_spheres.png', bbox_inches='tight', dpi=300, format='png')

# %%
KDTree(bin_r).query
ext_faces=mesh.faceCenters.value.T[mesh.exteriorFaces]
chr_faces=KDTree(ext_faces[ext_faces[:,0]**2+ext_faces[:,1]**2<(radius/1.1)**2])
d_chr = fp.CellVariable(mesh=mesh, name=r'$d_{chr}$', value = chr_faces.query(mesh.cellCenters.value.T)[0] + sigma_chr)
